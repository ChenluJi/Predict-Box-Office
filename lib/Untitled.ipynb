# %%
import pandas as pd
data = pd.read_csv('/Users/JJason/Desktop/rawdata.csv',index_col = False)

# %%
data
# Out:
#        Unnamed: 0                                                  0  \
# 0               0                  Captain America: Civil War (2016)
# 1               1                           X-Men: Apocalypse (2016)
# 2               2                      Mechanic: Resurrection (2016)
# 3               3                                    Warcraft (2016)
# 4               4                           The Boy Next Door (2015)
# 5               5                                The Shallows (2016)
# 6               6         Captain America: The Winter Soldier (2014)
# 7               7                               Don't Breathe (2016)
# 8               8                               Suicide Squad (2016)
# 9               9                            Now You See Me 2 (2016)
# 10             10          Batman v Superman: Dawn of Justice (2016)
# 11             11                                       Sully (2016)
# 12             12                        Central Intelligence (2016)
# ...

# %%
data.ix[4501,:]
# Out:
# Unnamed: 0                            4501
# 0                          Grabbers (2012)
# 1                          Status Released
# 2                Original Language English
# 3                           Runtime 1h 34m
# 4                                 Budget -
# 5                                Revenue -
# 6             Homepage http://grabbers.ie/
# 7                      Release Information
# 8                            Richard Coyle
# 9                             Ruth Bradley
# 10                           Russell Tovey
# 11                       Bronagh Gallagher
# 12                            David Pearse
# 13                             Lalor Roddy
# 14                        Full Cast & Crew
# 15                                     NaN
# Name: 4501, dtype: object
