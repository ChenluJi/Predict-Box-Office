# %%
import pandas as pd

# %%
data = pd.DataFrame()
for i in range(4):
    data1 = pd.read_csv('/Users/JJason/Documents/Study/summer project/Predict-Box-Office/data/feature_raw' + str(i+1) + '.csv')
    data = pd.concat([data,data1])

# %%
data.to_csv('/Users/JJason/Desktop/rawdata.csv', index = False)

# %%
data = pd.read_csv('/Users/JJason/Desktop/rawdata.csv')

# %%
na = pd.DataFrame()
index = []
for i in range(len(data)):
    if 'Original' in data.ix[i,1]:
        index.append(i)
        na = pd.concat([na,data[i:(i+1)]])
data = data.drop(index)
na = na.drop('1',axis = 1)

# %%
data.to_csv('/Users/JJason/Desktop/data.csv')

# %%
na.to_csv('/Users/JJason/Desktop/na.csv', header = None)

# %%
data = pd.read_csv('/Users/JJason/Desktop/data.csv', index_col = 'Unnamed: 0')

# %%
na = pd.read_csv('/Users/JJason/Desktop/na.csv',index_col = '45')

# %%
pd.concat([data,na])
# Out:
#             0                                               1  \
# 0         NaN                                             NaN
# 1         NaN                                             NaN
# 2         NaN                                             NaN
# 3         NaN                                             NaN
# 4         NaN                                             NaN
# 5         NaN                                             NaN
# 6         NaN                                             NaN
# 7         NaN                                             NaN
# 8         NaN                                             NaN
# 9         NaN                                             NaN
# 10        NaN                                             NaN
# 11        NaN                                             NaN
# 12        NaN                                             NaN
# 13        NaN                                             NaN
# ...

# %%
data
# Out:
#                                                        0  \
# 0                      Captain America: Civil War (2016)
# 1                               X-Men: Apocalypse (2016)
# 2                          Mechanic: Resurrection (2016)
# 3                                        Warcraft (2016)
# 4                               The Boy Next Door (2015)
# 5                                    The Shallows (2016)
# 6             Captain America: The Winter Soldier (2014)
# 7                                   Don't Breathe (2016)
# 8                                   Suicide Squad (2016)
# 9                                Now You See Me 2 (2016)
# 10             Batman v Superman: Dawn of Justice (2016)
# 11                                          Sully (2016)
# 12                           Central Intelligence (2016)
# 13                             Mad Max: Fury Road (2015)
# 14     Teenage Mutant Ninja Turtles: Out of the Shado...
# ...

# %%
na
# Out:
#          45                              Russian Lolita (2007)  \
# 0        67                               Emerald Green (2016)
# 1        92                              Train to Busan (2016)
# 2        97                            Student Services (2010)
# 3       100                What Every Frenchwoman Wants (1986)
# 4       104                                      Desire (2011)
# 5       157                            The Intouchables (2011)
# 6       172                           Princess Mononoke (1997)
# 7       210                             Pan's Labyrinth (2006)
# 8       219  Tini: The Movie - The New Life of Violetta (2016)
# 9       233                       A Conspiracy of Faith (2016)
# 10      251                               Spirited Away (2001)
# 11      289                              Friend Request (2016)
# 12      300                      Leon: The Professional (1994)
# 13      314        Sexual Chronicles of a French Family (2012)
# ...
